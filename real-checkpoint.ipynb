# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("bankig loan.csv")

# %%
data
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
#Making data set clean to perform numerical operation 
# replaced the $ sign and - to null value(NaN)
data.replace({'\$': ''}, regex=True, inplace=True)
data.replace({'\-':np.nan}, regex=True, inplace=True)
data.replace({'\,':''},regex=True,inplace=True)
data.replace({'\(':''},regex=True,inplace=True)
data.replace({'\)':''},regex=True,inplace=True)
data
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
data.dtypes
# Out:
# Segment                   object
# Country                   object
#  Product                  object
#  Discount Band            object
# Units Sold               float64
#  Manufacturing Price      object
#  Sale Price               object
#  Gross Sales              object
#  Discounts                object
#   Sales                   object
#  COGS                     object
#  Profit                   object
# Date                      object
# Month Number               int64
#  Month Name               object
# Year                       int64
# dtype: object

# %%
# Assuming your DataFrame is named 'data'
# Convert specific columns to float
columns_to_convert = [' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ', '  Sales ', ' COGS ',' Profit ']
data[columns_to_convert] = data[columns_to_convert].astype(float)

# Display the modified DataFrame
data.dtypes
data
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
import pandas as pd

# DataFrame is named 'data'
# Checking for missing values in the entire DataFrame
print("Checking Null values in Entire Dataset",data.isnull())
# Out:
# Checking Null values in Entire Dataset      Segment  Country   Product    Discount Band   Units Sold  \
# 0      False    False      False            False       False
# 1      False    False      False            False       False
# 2      False    False      False            False       False
# 3      False    False      False            False       False
# 4      False    False      False            False       False
# ..       ...      ...        ...              ...         ...
# 695    False    False      False            False       False
# 696    False    False      False            False       False
# 697    False    False      False            False       False
# 698    False    False      False            False       False
# 699    False    False      False            False       False
#
#       Manufacturing Price    Sale Price    Gross Sales    Discounts   \
# 0                    False         False          False         True
# ...

# %%
print("Checking Null values in Entire Dataset",data.isnull())
# Checking the total number of missing values in each column
print("Null values in coloumn wise:\n",data.isnull().sum())

# Checking the total number of missing values in the entire DataFrame
print("total no of Null values=",data.isnull().sum().sum())
# Out:
# Checking Null values in Entire Dataset      Segment  Country   Product    Discount Band   Units Sold  \
# 0      False    False      False            False       False
# 1      False    False      False            False       False
# 2      False    False      False            False       False
# 3      False    False      False            False       False
# 4      False    False      False            False       False
# ..       ...      ...        ...              ...         ...
# 695    False    False      False            False       False
# 696    False    False      False            False       False
# 697    False    False      False            False       False
# 698    False    False      False            False       False
# 699    False    False      False            False       False
#
#       Manufacturing Price    Sale Price    Gross Sales    Discounts   \
# 0                    False         False          False         True
# ...

# %%
print("Total Unit Sold:",data['Units Sold'].sum(),"\n")
print("Total Gross Sales:",data[' Gross Sales '].sum(),"\n")
print("Total Discounts:",data[' Discounts '].sum(),"\n")
print("Total COGS:",data[' COGS '].sum(),"\n")
print("Total profit:",data[' Profit '].sum(),"\n")
# Out:
# Total Unit Sold: 1125806.0
#
# Total Gross Sales: 127931598.5
#
# Total Discounts: 9205248.27
#
# Total COGS: 101832648.0
#
# Total profit: 18448344.79

# %%
Segment=print(data['Segment'].unique())
country=print(data['Country'].unique())
product=print(data[' Product '].unique())
disc_band=print(data[' Discount Band '].unique())
month_name=print(data[' Month Name '].unique())
year=print(data['Year'].unique())
# Out:
# ['Government' 'Midmarket' 'Channel Partners' 'Enterprise' 'Small Business']
# ['Canada' 'Germany' 'France' 'Mexico' 'United States of America']
# [' Carretera ' ' Montana ' ' Paseo ' ' Velo ' ' VTT ' ' Amarilla ']
# [' None ' ' Low ' ' Medium ' ' High ']
# [' January ' ' June ' ' December ' ' March ' ' July ' ' August '
#  ' September ' ' October ' ' February ' ' November ' ' April ' ' May ']
# [2014 2013]

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

data.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold  \
# 0  Government   Canada   Carretera            None       1618.5
# 1  Government  Germany   Carretera            None       1321.0
# 2   Midmarket   France   Carretera            None       2178.0
# 3   Midmarket  Germany   Carretera            None        888.0
# 4   Midmarket   Mexico   Carretera            None       2470.0
#
#     Manufacturing Price    Sale Price    Gross Sales    Discounts     Sales   \
# 0                    3.0          20.0        32370.0          NaN   32370.0
# 1                    3.0          20.0        26420.0          NaN   26420.0
# 2                    3.0          15.0        32670.0          NaN   32670.0
# 3                    3.0          15.0        13320.0          NaN   13320.0
# 4                    3.0          15.0        37050.0          NaN   37050.0
#
#      COGS    Profit       Date  Month Number  Month Name   Year
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4   Units Sold             700 non-null    float64
#  5    Manufacturing Price   700 non-null    float64
#  6    Sale Price            700 non-null    float64
#  7    Gross Sales           700 non-null    float64
#  8    Discounts             647 non-null    float64
#  9     Sales                700 non-null    float64
#  10   COGS                  700 non-null    float64
#  11   Profit                695 non-null    float64
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
# ...

# %%
sns.barplot(y=data[' Profit '],x=data['Country'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel=' Profit '>

# %%
sns.distplot(data[' Gross Sales '])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel=' Gross Sales ', ylabel='Density'>

# %%
sns.jointplot(x=data[' Profit '],y=data['  Sales '])

# %%
import pandas as pd
import matplotlib.pyplot as plt

column_name = ' Product '  

value_counts = data[column_name].value_counts()

# Your plotting code here
plt.figure(figsize=(6, 6))  
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90,
        colors=plt.cm.Paired.colors)


plt.title(f'Pie Chart for {column_name}')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'data'
# Assuming you want to create a histogram for a specific column, replace 'column_name' with the actual column name
column_name = ' COGS '

# Your plotting code here
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.hist(data[column_name], bins=24, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.title(f'Histogram for {column_name}')

# Show the grid
plt.grid(axis='y')

# Display the plot
plt.show()
